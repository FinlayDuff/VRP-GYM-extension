# %% [markdown]
# # Import the packages and modules

# %%
from gym_vrp.envs import VRPEnv, IRPEnv, TSPEnv, SantaIRPEnv
from agents import TSPAgent, IRPAgent, VRPAgent

import torch

# %% [markdown]
# ## Train the agent

# %%
batch_size = 256
seed = 69
num_nodes = 20

# %%
env_tsp = TSPEnv(num_nodes=num_nodes, batch_size=batch_size, seed=seed)

agent_tsp = TSPAgent(
    seed=seed, csv_path=f"./train_logs/loss_log_tsp_{num_nodes}_{seed}.csv",
)
agent_tsp.train(
    env_tsp,
    epochs=851,
    check_point_dir=f"./check_points/tsp_{num_nodes}_{seed}/",
        )
# Out:
# INFO:root:Start Training
# INFO:root:Update Baseline
# INFO:root:Epoch 0 finished - Loss: 13.876494407653809, Advantage: -0.40456193685531616 Dist: -9.354199409484863
# INFO:root:Update Baseline
# INFO:root:Epoch 1 finished - Loss: 64.24781799316406, Advantage: -2.009838104248047 Dist: -7.842212200164795
# replacing baceline
# INFO:root:Update Baseline
# INFO:root:Epoch 2 finished - Loss: 83.71669006347656, Advantage: -3.00699520111084 Dist: -6.919619560241699
# replacing baceline
# INFO:root:Update Baseline
# INFO:root:Epoch 3 finished - Loss: 91.60370635986328, Advantage: -3.6138744354248047 Dist: -6.316587448120117
# INFO:root:Update Baseline
# INFO:root:Epoch 4 finished - Loss: 90.36526489257812, Advantage: -3.9176716804504395 Dist: -6.045804023742676
# replacing baceline
# INFO:root:Update Baseline
# INFO:root:Epoch 5 finished - Loss: 85.16291046142578, Advantage: -3.9511280059814453 Dist: -5.853900909423828
# replacing baceline
# INFO:root:Update Baseline
# ...

# %% [markdown]
# ## Visualise the actions of the agent in the environments

# %%
env = TSPEnv(num_nodes=num_nodes, batch_size=batch_size, seed=seed, num_draw=3)
TSPModel='./check_points/tsp_20_69/model_epoch_850.pt'

# %%
env.enable_video_capturing(
    video_save_path=f"./videos/video_test_{num_nodes}_{seed}.mp4"
)

# %%
agent = TSPAgent(seed=seed)
agent.model.load_state_dict(torch.load("./check_points/tsp_20_69/model_epoch_850.pt"))
# Out:
# <All keys matched successfully>

# %%
loss_a = agent.evaluate(env)

# %%
env.vid.close()
# Out:
# Moviepy - Building video ./videos/video_test_20_69.mp4.
# Moviepy - Writing video ./videos/video_test_20_69.mp4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 env.vid.close()
#
# File c:\Users\jfgal\anaconda3\envs\gym_vrp\lib\site-packages\gym\wrappers\monitoring\video_recorder.py:158, in VideoRecorder.close(self)
#     156     logger.debug(f"Closing video encoder: path={self.path}")
#     157     clip = ImageSequenceClip(self.recorded_frames, fps=self.frames_per_sec)
# --> 158     clip.write_videofile(self.path)
#     159 else:
#     160     # No frames captured. Set metadata.
#     161     if self.metadata is None:
#
# File c:\Users\jfgal\anaconda3\envs\gym_vrp\lib\site-packages\decorator.py:232, in fun(*args, **kw)
#     230 evaldict = dict(_call_=caller, _func_=func)
#     231 es = ''
# --> 232 for i, extra in enumerate(extras):
# ...
